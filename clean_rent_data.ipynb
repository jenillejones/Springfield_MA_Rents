# %% [markdown]
# # Clean rent data #

# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
pd.set_option('display.max_columns', None)

# %%
rent_all_columns = pd.read_csv('rent_data_all.csv')

# %%
rent_all_columns.head(2)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
# 1           1        1.0       1.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP       homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT      APARTMENT        True
# 1            -1   FOR_RENT         FOR_RENT  SINGLE_FAMILY       False
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
# 1                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned   latitude  livingArea  \
# 0                  False         False          False  42.104000       617.0
# 1                  False         False          False  42.095623      1550.0
#
#    longitude   price  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
# 1 -72.496870   750.0        750.0            False    MA
#
#                    streetAddress         unit  zipcode        zpid  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55     1103  2066685043
# 1                 42 Catalina Dr          NaN     1128    56205755
#
#   lotAreaUnit  lotAreaValue  rentZestimate  taxAssessedValue  zestimate  \
# 0         NaN           NaN            NaN               NaN        NaN
# 1       acres      0.579982         2400.0          212200.0   304700.0
#
#    datePriceChanged  priceChange priceReduction
# 0               NaN          NaN            NaN
# 1               NaN          NaN            NaN

# %% [markdown]
# ### Renaming columns ###

# %%
rent_all_columns=rent_all_columns.rename(columns={'livingArea':'area', 'price':'rent', 'streetAddress':'street_address'})

# %% [markdown]
# ### Adding a 0 prefix to all zipcodes ###

# %%
rent_all_columns['zipcode']=rent_all_columns['zipcode'].apply(lambda x: '{0:0>5}'.format(x))

# %%
rent_all_columns.head(1)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP   homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT  APARTMENT        True
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned  latitude   area  \
# 0                  False         False          False    42.104  617.0
#
#    longitude    rent  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
#
#                   street_address         unit zipcode        zpid lotAreaUnit  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55   01103  2066685043         NaN
#
#    lotAreaValue  rentZestimate  taxAssessedValue  zestimate  datePriceChanged  \
# 0           NaN            NaN               NaN        NaN               NaN
#
#    priceChange priceReduction
# 0          NaN            NaN

# %% [markdown]
# ## List of Springfield, MA neighborhoods with zipcodes ##
# ### May be able to make this into a dictionary and use 'clean swiss data' function in notebook 2 to assign neighborhood names to zip codes ###
#
# ### *combined a few of the zip codes that had mulitple neighborhoods associated with them ###
#
#     Atwater Park, 01107
#     Downtown, 01103, 01105
#     East Forest Park, 01118
#     Forest Park, 01108
#     Indian Orchard, 01151
#     Liberty Heights & East Springfield, 01104
#     Maple Hill/Ridgewood, 01105
#     McKnight, 01109
#     Pine Point/Boston Road, 01109, 01119
#     Sixteen Acres, 01118, 01119, 01128, 01129

# %%
hood_dict = {'01107':'Atwater Park',
             '01103':'Downtown',
             '01118':'East Forest Park*',
             '01108':'Forest Park',
             '01151':'Indian Orchard',
             '01104':'Liberty Heights & East Springfield;',
             '01105':'Maple Hill/Ridgewood*',
             '01109':'McKnight*',
             '01119':'Pine Point/Boston Road*',
             '01128':'Sixteen Acres',
             '01129':'SixteenAcres',
            }

# %%
def create_new_features(df):
    # Add rent categories
    rent_all_columns['sqft_cost'] =  rent_all_columns["rent"] /  rent_all_columns["area"]
    descr_rents =  rent_all_columns['sqft_cost'].describe()

    quantiles =  rent_all_columns['sqft_cost'].quantile(q=[0.15, 0.5, 0.85])
    cheap = quantiles[0.15]
    average = quantiles[0.5]
    expensive = quantiles[0.85]

    rent_all_columns["cost_per_square_feet"] = np.where(
         rent_all_columns['sqft_cost'] < cheap,
        0,
        np.where(
            ( rent_all_columns['sqft_cost'] >= cheap) & ( rent_all_columns['sqft_cost'] < average),
            1,
            np.where(
                ( rent_all_columns['sqft_cost'] >= average) & ( rent_all_columns['sqft_cost'] < expensive),
                2,
                3,
            ),
        ),
    )
    rent_all_columns["hover_strings_scatter"] = [
    f"Address: {street}, {place},<br>Rooms: {rooms}, <br>Rent: USD {rent}"
    for street, place, rooms, rent in zip(
        rent_all_columns["street_address"],
        rent_all_columns["city"],
        rent_all_columns["bedrooms"],
        rent_all_columns["rent"],
        )
    ]
    return  rent_all_columns
rent_all_columns.head(1)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP   homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT  APARTMENT        True
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned  latitude   area  \
# 0                  False         False          False    42.104  617.0
#
#    longitude    rent  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
#
#                   street_address         unit zipcode        zpid lotAreaUnit  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55   01103  2066685043         NaN
#
#    lotAreaValue  rentZestimate  taxAssessedValue  zestimate  datePriceChanged  \
# 0           NaN            NaN               NaN        NaN               NaN
#
#    priceChange priceReduction
# 0          NaN            NaN

# %% [markdown]
# ## Adding 'sqft_cost' column ##

# %%
rent_all_columns['sqft_cost'] =  rent_all_columns["rent"] /  rent_all_columns["area"]
descr_rents =  rent_all_columns['sqft_cost'].describe()
rent_all_columns.head(1)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP   homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT  APARTMENT        True
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned  latitude   area  \
# 0                  False         False          False    42.104  617.0
#
#    longitude    rent  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
#
#                   street_address         unit zipcode        zpid lotAreaUnit  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55   01103  2066685043         NaN
#
#    lotAreaValue  rentZestimate  taxAssessedValue  zestimate  datePriceChanged  \
# 0           NaN            NaN               NaN        NaN               NaN
#
#    priceChange priceReduction  sqft_cost
# 0          NaN            NaN   1.688817

# %% [markdown]
# ## Adding 'neighborhood' column ##

# %%
rent_all_columns['neighborhood'] = rent_all_columns['zipcode'].apply(lambda x: hood_dict.get(x))
rent_all_columns.head(5)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
# 1           1        1.0       1.0  Springfield     USA      USD
# 2           2        1.5       3.0  Springfield     USA      USD
# 3           3        2.0       3.0  Springfield     USA      USD
# 4           4        1.0       2.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP       homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT      APARTMENT        True
# 1            -1   FOR_RENT         FOR_RENT  SINGLE_FAMILY       False
# 2            -1   FOR_RENT         FOR_RENT      TOWNHOUSE       False
# 3            -1   FOR_RENT         FOR_RENT      TOWNHOUSE       False
# 4            -1   FOR_RENT         FOR_RENT  SINGLE_FAMILY       False
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
# 1                True                    False             False
# 2                True                    False             False
# 3                True                    False             False
# 4                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned   latitude    area  \
# 0                  False         False          False  42.104000   617.0
# 1                  False         False          False  42.095623  1550.0
# 2                  False         False          False  42.143475  1200.0
# 3                  False         False          False  42.098564  1400.0
# 4                  False         False          False  42.140114   864.0
#
#    longitude    rent  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
# 1 -72.496870   750.0        750.0            False    MA
# 2 -72.484520  1650.0       1650.0            False    MA
# 3 -72.570010  2300.0       2300.0            False    MA
# 4 -72.566666  1700.0       1700.0            False    MA
#
#                   street_address         unit zipcode        zpid lotAreaUnit  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55   01103  2066685043         NaN
# 1                 42 Catalina Dr          NaN   01128    56205755       acres
# 2               62 Biddle St #62         # 62   01129  2061445071         NaN
# 3                    13 Beech St          NaN   01105    56202635        sqft
# 4                     38 Lang St          NaN   01104    56217208        sqft
#
#    lotAreaValue  rentZestimate  taxAssessedValue  zestimate  datePriceChanged  \
# 0           NaN            NaN               NaN        NaN               NaN
# 1      0.579982         2400.0          212200.0   304700.0               NaN
# 2           NaN            NaN               NaN        NaN               NaN
# 3   7405.000000         2188.0           19000.0   234800.0               NaN
# 4   5662.000000         1500.0          152200.0   213900.0               NaN
#
#    priceChange priceReduction  sqft_cost                         neighborhood
# 0          NaN            NaN   1.688817                             Downtown
# 1          NaN            NaN   0.483871                        Sixteen Acres
# 2          NaN            NaN   1.375000                         SixteenAcres
# 3          NaN            NaN   1.642857                Maple Hill/Ridgewood*
# 4          NaN            NaN   1.967593  Liberty Heights & East Springfield;

# %% [markdown]
# ## Adding 'hover_strings_scatter' column ##

# %%
rent_all_columns["hover_strings_scatter"] = [
    f"Address: {street}, {place},<br>Rooms: {rooms}, <br>Rent: USD {rent}"
    for street, place, rooms, rent in zip(
        rent_all_columns["street_address"],
        rent_all_columns["city"],
        rent_all_columns["bedrooms"],
        rent_all_columns["rent"],
        )
    ]
rent_all_columns.head(1)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP   homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT  APARTMENT        True
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned  latitude   area  \
# 0                  False         False          False    42.104  617.0
#
#    longitude    rent  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
#
#                   street_address         unit zipcode        zpid lotAreaUnit  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55   01103  2066685043         NaN
#
#    lotAreaValue  rentZestimate  taxAssessedValue  zestimate  datePriceChanged  \
# 0           NaN            NaN               NaN        NaN               NaN
#
#    priceChange priceReduction  sqft_cost neighborhood  \
# 0          NaN            NaN   1.688817     Downtown
#
#                                hover_strings_scatter
# 0  Address: 193 Worthington St #71DFDFD55, Spring...

# %% [markdown]
# ## Adding 'quantile calculations' ##

# %%
quantiles =  rent_all_columns['sqft_cost'].quantile(q=[0.15, 0.5, 0.85])
cheap = quantiles[0.15]
average = quantiles[0.5]
expensive = quantiles[0.85]

rent_all_columns["cost_per_square_feet"] = np.where(rent_all_columns['sqft_cost'] < cheap, 0,
        np.where(( rent_all_columns['sqft_cost'] >= cheap) & ( rent_all_columns['sqft_cost'] < average), 1,
        np.where(( rent_all_columns['sqft_cost'] >= average) & ( rent_all_columns['sqft_cost'] < expensive), 2, 3,
            ),
        ),
    )
rent_all_columns.head(1)
# Out:
#    Unnamed: 0  bathrooms  bedrooms         city country currency  \
# 0           0        1.0       1.0  Springfield     USA      USD
#
#    daysOnZillow homeStatus homeStatusForHDP   homeType  isFeatured  \
# 0            -1   FOR_RENT         FOR_RENT  APARTMENT        True
#
#    isNonOwnerOccupied  isPreforeclosureAuction  isPremierBuilder  \
# 0                True                    False             False
#
#    isRentalWithBasePrice  isUnmappable  isZillowOwned  latitude   area  \
# 0                  False         False          False    42.104  617.0
#
#    longitude    rent  priceForHDP  shouldHighlight state  \
# 0 -72.592384  1042.0       1042.0            False    MA
#
#                   street_address         unit zipcode        zpid lotAreaUnit  \
# 0  193 Worthington St #71DFDFD55  # 71dfdfd55   01103  2066685043         NaN
#
#    lotAreaValue  rentZestimate  taxAssessedValue  zestimate  datePriceChanged  \
# 0           NaN            NaN               NaN        NaN               NaN
#
#    priceChange priceReduction  sqft_cost neighborhood  \
# 0          NaN            NaN   1.688817     Downtown
#
#                                hover_strings_scatter  cost_per_square_feet
# 0  Address: 193 Worthington St #71DFDFD55, Spring...                     3

# %% [markdown]
# ## Getting only wanted columns ##

# %%
rent_data = rent_all_columns[['bedrooms', 'bathrooms', 'area', 'rent', 'street_address', 'zipcode', 'neighborhood', 'city', 'sqft_cost','hover_strings_scatter','cost_per_square_feet']]
rent_all_columns.fillna('NA')
rent_data.head(10)
# Out:
#    bedrooms  bathrooms    area    rent                 street_address zipcode  \
# 0       1.0        1.0   617.0  1042.0  193 Worthington St #71DFDFD55   01103
# 1       1.0        1.0  1550.0   750.0                 42 Catalina Dr   01128
# 2       3.0        1.5  1200.0  1650.0               62 Biddle St #62   01129
# 3       3.0        2.0  1400.0  2300.0                    13 Beech St   01105
# 4       2.0        1.0   864.0  1700.0                     38 Lang St   01104
# 5       3.0        1.5  2300.0  3000.0          (undisclosed Address)   01107
# 6       4.0        1.0     NaN  1800.0                  12 Wareham St   01108
# 7       2.0        1.5  1150.0  1750.0                  184 Draper St   01108
# 8       4.0        3.0  1560.0  2900.0                   111 Lumae St   01119
# 9       2.0        1.0   882.0  1450.0               25 Ruskin St #25   01108
#
#                           neighborhood         city  sqft_cost  \
# 0                             Downtown  Springfield   1.688817
# 1                        Sixteen Acres  Springfield   0.483871
# 2                         SixteenAcres  Springfield   1.375000
# 3                Maple Hill/Ridgewood*  Springfield   1.642857
# 4  Liberty Heights & East Springfield;  Springfield   1.967593
# 5                         Atwater Park  Springfield   1.304348
# 6                          Forest Park  Springfield        NaN
# 7                          Forest Park  Springfield   1.521739
# 8              Pine Point/Boston Road*  Springfield   1.858974
# 9                          Forest Park  Springfield   1.643991
#
#                                hover_strings_scatter  cost_per_square_feet
# 0  Address: 193 Worthington St #71DFDFD55, Spring...                     3
# 1  Address: 42 Catalina Dr, Springfield,<br>Rooms...                     0
# 2  Address: 62 Biddle St #62, Springfield,<br>Roo...                     1
# 3  Address: 13 Beech St, Springfield,<br>Rooms: 3...                     2
# 4  Address: 38 Lang St, Springfield,<br>Rooms: 2....                     3
# 5  Address: (undisclosed Address), Springfield,<b...                     1
# 6  Address: 12 Wareham St, Springfield,<br>Rooms:...                     3
# 7  Address: 184 Draper St, Springfield,<br>Rooms:...                     2
# 8  Address: 111 Lumae St, Springfield,<br>Rooms: ...                     3
# 9  Address: 25 Ruskin St #25, Springfield,<br>Roo...                     2

# %% [markdown]
# ## *Need to add remaing 'create new features' function from notebook 2* ##

# %% [markdown]
# def create_new_features(df):
#     # Add rent categories
#     rent_all_columns['sqft_cost'] =  rent_all_columns["rent"] /  rent_all_columns["area"]
#     descr_rents =  rent_all_columns['sqft_cost'].describe()
#
#     quantiles =  rent_all_columns['sqft_cost'].quantile(q=[0.15, 0.5, 0.85])
#     cheap = quantiles[0.15]
#     average = quantiles[0.5]
#     expensive = quantiles[0.85]
#
#     rent_all_columns["cost_per_square_feet"] = np.where(
#          rent_all_columns['sqft_cost'] < cheap,
#         0,
#         np.where(
#             ( rent_all_columns['sqft_cost'] >= cheap) & ( rent_all_columns['sqft_cost'] < average),
#             1,
#             np.where(
#                 ( rent_all_columns['sqft_cost'] >= average) & ( rent_all_columns['sqft_cost'] < expensive),
#                 2,
#                 3,
#             ),
#         ),
#     )
#     rent_all_columns["hover_strings_scatter"] = [
#     f"Address: {street}, {place},<br>Rooms: {rooms}, <br>Rent: USD {rent}"
#     for street, place, rooms, rent in zip(
#         rent_all_columns["street_address"],
#         rent_all_columns["city"],
#         rent_all_columns["bedrooms"],
#         rent_all_columns["rent"],
#         )
#     ]
#     return  rent_all_columns

# %% [markdown]
# ## ***Need to re-add 'area' to function once NaN values are taken care of*** ##

# %%
 # Hover strings
#rent_all_columns["hover_strings_scatter"] = [
#    f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m²,<br>Rent: USD {rent}"
#    for street, place, rooms, size, rent in zip(
#        rent_all_columns["street_address"],
#        rent_all_columns["city"],
#        rent_all_columns["bedrooms"],
#        rent_all_columns["area"],
#        rent_all_columns["rent"],
#    )
#]

rent_all_columns["hover_strings_scatter"] = [
    f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m², <br>Rent: USD {rent}"
    for street, place, rooms, rent in zip(
        rent_all_columns["street_address"],
        rent_all_columns["city"],
        rent_all_columns["bedrooms"],
        rent_all_columns["area"],
        rent_all_columns["rent"],
    )
]

#print(rent_all_columns.fillna('NA'))
rent_data.head(10)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22296\4265565214.py in <cell line: 13>()
#      11 #]
#      12
# ---> 13 rent_all_columns["hover_strings_scatter"] = [
#      14    f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m², <br>Rent: USD {rent}"
#      15    for street, place, rooms, rent in zip(
#
# ~\AppData\Local\Temp\ipykernel_22296\4265565214.py in <listcomp>(.0)
#      11 #]
#      12
# ---> 13 rent_all_columns["hover_strings_scatter"] = [
#      14    f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m², <br>Rent: USD {rent}"
#      15    for street, place, rooms, rent in zip(
#
# ValueError: too many values to unpack (expected 4)

# %%
rent_all_columns["hover_strings_scatter"] = [
    f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m², <br>Rent: USD {rent}"
    for street, place, rooms, rent in zip(
        rent_all_columns["street_address"],
        rent_all_columns["city"],
        rent_all_columns["bedrooms"],
        rent_all_columns["area"],
        rent_all_columns["rent"],
    )
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22296\3446668730.py in <cell line: 1>()
# ----> 1 rent_all_columns["hover_strings_scatter"] = [
#       2     f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m², <br>Rent: USD {rent}"
#       3     for street, place, rooms, rent in zip(
#       4         rent_all_columns["street_address"],
#       5         rent_all_columns["city"],
#
# ~\AppData\Local\Temp\ipykernel_22296\3446668730.py in <listcomp>(.0)
# ----> 1 rent_all_columns["hover_strings_scatter"] = [
#       2     f"Address: {street}, {place},<br>Rooms: {rooms}, Floor Space: {round(size)}m², <br>Rent: USD {rent}"
#       3     for street, place, rooms, rent in zip(
#       4         rent_all_columns["street_address"],
#       5         rent_all_columns["city"],
#
# ValueError: too many values to unpack (expected 4)

# %% [markdown]
# # Rent Data all clean and making csv file and getting other information #

# %%
rent_data.head(2)

# %%
rent_data.to_csv('rent_data_clean_spfld.csv', encoding='utf-8')

# %%
rent_data.info()

# %%
rent_data.describe()

# %%
rent_data.value_counts()
